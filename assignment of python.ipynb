# %%
##to check the current working dictionary
import os
os.getcwd()
# Out:
# 'C:\\Users\\j0han'

# %%
##to read the dataset to the environment
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_excel('iris.xls')
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
##to display the SL coloumn in the dataset
print(data['SL'])
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SL, Length: 150, dtype: float64

# %%
##to display the SW coloumn in the dataset
print(data['SW'])
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SW, Length: 150, dtype: float64

# %%
##to display the PL coloumn in the dataset
print(data['PL'])
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PL, Length: 150, dtype: float64

# %%
##to display the PW coloumn in the dataset
print(data['PW'])
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: PW, Length: 150, dtype: float64

# %%
##to calculate the mean of the each coloumn of the dataset
data.iloc[:,0:4].apply(np.mean)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
##to check for null values present in the dataset
data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
##visualizations of the dataset using box plot and whisker plot
data.plot(kind='box',subplots=True,layout=(3,2),figsize=(8,12));

# %%
data.hist(figsize=(12,12))
plt.show()

# %%
data.corr()
# Out:
#           SL        SW        PL        PW
# SL  1.000000 -0.109369  0.871754  0.817954
# SW -0.109369  1.000000 -0.420516 -0.356544
# PL  0.871754 -0.420516  1.000000  0.962757
# PW  0.817954 -0.356544  0.962757  1.000000

# %%
##visualization using heatmap
sns.heatmap(data.corr(),annot=True,cmap='Wistia')
# Out:
# <AxesSubplot:>

# %%
##visualisations of the dataset using pairplot
sns.pairplot(data)
